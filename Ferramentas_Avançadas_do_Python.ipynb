# %% [markdown]
#  ** Ferramentas Avançadas do Python
#
# - Programação Orientada a objetos
# - Modulos e Pacotes
# - A Biblioteca Padrão
# - Importando Módulos
# - Pacotes Obrigatórios para Finanças e Ciência de Dados
# - Trabalhando com Arrays
# - Gerando Numeros Aleatórios
# - Uma nota sobre o uso de dados Financeiro no Python
# - Fontes de dados Financeiros
# - Acessando os Arquivos Notebook
# - Importando e Organizando seus dados no Python
# - Alterando o Indice dos dados de sua Série temporal
# - Reiniciando o Kernel do Jupyter

# %%
# Importando Módulos

## Tarefa:
###    Importe o módulo "math"
    
####    sqrt() - calcula a raiz quadrada de um argumento

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt

# %%
sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt as s

# %%
s(36)
# Out:
# 6.0

# %%
import math as m

# %%
m.sqrt(49)
# Out:
# 7.0

# %%
from math import *

# %%
sqrt(64)
# Out:
# 8.0

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %%
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %%
# Pacotes Obrigatórios para Finanças e Ciência de Dados

## - NumPy um pacote de terceiros que nos permite trabalhar com arrays multidimensionais
### * array representam uma maneira poderosa de organizar e processar dados

## - Pandas nos permite organizar os dados em uma forma tabular e anexar rótulos descrritivos as linhas e colunas da tabela
### * Pandas é adequado para trabalhar com séries temporais e banco de dados enormes

## - matplotlib uma biblioteca de graficos 2D especialmente projetada para visualização de calculos Numpy

## - Scipy (matematica, machine learning, inteligencia artificial e engenharia)

## - math (Funções matematicas)

## - random (gera numeros aleatórios)

## - statsmodels - estatística descritiva, plotagem de

# %%
import numpy

# %%
import pandas

# %%
import matplotlib

# %%
import math

# %%
import statsmodels

# %%
import pandas_datareader

# %%
# Trabalhado com Array

## array() - retorna uma estrutura de dados no formato de array Numpy

# %%
import numpy as np

# %%
a = np.array([[0,1,2,3],[4,5,6,7]])
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
a.shape
# Out:
# (2, 4)

# %%
a[1,3]
# Out:
# 7

# %%
a[1,2] = 8
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 8, 7]])

# %%
a[0]
# Out:
# array([0, 1, 2, 3])

# %%
a[1]
# Out:
# array([4, 5, 8, 7])

# %%
# Gerando numeros Aleatorios

## random.randint() - randomiza em um intervalo fornecido e fornece um valor inteiro

# %%
import random

# %%
prob = random.random()
print(prob)
# Out:
# 0.8438758012355709

# %%
number = random.randint(1,6)
print(number)
# Out:
# 2

# %%
import numpy as np

# %%
np.random.randint(1,6,(4,6))
# Out:
# array([[2, 3, 2, 4, 4, 2],
#        [4, 2, 5, 5, 4, 5],
#        [4, 5, 4, 4, 5, 2],
#        [1, 3, 1, 3, 5, 4]])

# %%
# Uma nota sobre o uso de dados Financeiro no Python

## Fonte on-line: Pago x Gratuito

### Pago - dados bem estruturados, valores ausentes (raramente)

### Gratuito - boa qualidade de dados, não tão precisos ou tão ricos em comparação com os dados fornecidos por sites pagos


# Fontes de dados Financeiros

## IEX, Morningstar, Alpha Vantage, Quandl Apis, entre muitos outros

## Yahoo Finance, Google Finance

### usar os arquivos CSV (Aplicação do curso)

# Acessando os Arquivos Notebook

# %%
# Importando e Organizando seus dados no Python

# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(np.random.random(5), name = "Column 01")

# %%
ser
# Out:
# 0    0.085264
# 1    0.462647
# 2    0.273978
# 3    0.938171
# 4    0.290529
# Name: Column 01, dtype: float64

# %%
ser[2]
# Out:
# 0.27397766845282

# %%
from pandas_datareader import data as wb

# %%
## Ticker: Procter & Gamble - PG / Apple - AAPL / Microsoft - MSFT

# %%
PG = wb.DataReader('PG', data_source='yahoo', start='1995-1-1')

# %%
PG
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 1995-01-03   15.625000   15.437500   15.468750   15.593750   3318400.0
# 1995-01-04   15.656250   15.312500   15.531250   15.468750   2218800.0
# 1995-01-05   15.437500   15.218750   15.375000   15.250000   2319600.0
# 1995-01-06   15.406250   15.156250   15.156250   15.281250   3438000.0
# 1995-01-09   15.406250   15.187500   15.343750   15.218750   1795200.0
# ...                ...         ...         ...         ...         ...
# 2021-05-24  138.800003  137.729996  138.000000  137.960007   6981300.0
# 2021-05-25  138.479996  136.750000  138.050003  138.429993   8142400.0
# 2021-05-26  138.860001  137.869995  138.789993  138.119995   8122900.0
# 2021-05-27  138.279999  134.660004  138.119995  134.979996  33095700.0
# 2021-05-28  136.130005  134.639999  135.149994  134.850006  10477100.0
#
#              Adj Close
# Date
# 1995-01-03    8.114557
# 1995-01-04    8.049510
# 1995-01-05    7.935676
# ...

# %%
# Analisar os dados

# %%
PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6649 entries, 1995-01-03 to 2021-05-28
# Data columns (total 6 columns):
# High         6649 non-null float64
# Low          6649 non-null float64
# Open         6649 non-null float64
# Close        6649 non-null float64
# Volume       6649 non-null float64
# Adj Close    6649 non-null float64
# dtypes: float64(6)
# memory usage: 363.6 KB

# %%
PG.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.114557
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   8.049510
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.935676
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   7.951943
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.919417

# %%
PG.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-05-24  138.800003  137.729996  138.000000  137.960007   6981300.0
# 2021-05-25  138.479996  136.750000  138.050003  138.429993   8142400.0
# 2021-05-26  138.860001  137.869995  138.789993  138.119995   8122900.0
# 2021-05-27  138.279999  134.660004  138.119995  134.979996  33095700.0
# 2021-05-28  136.130005  134.639999  135.149994  134.850006  10477100.0
#
#              Adj Close
# Date
# 2021-05-24  137.960007
# 2021-05-25  138.429993
# 2021-05-26  138.119995
# 2021-05-27  134.979996
# 2021-05-28  134.850006

# %%
 PG.head(20)
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.114557
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   8.049510
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.935676
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   7.951943
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.919417
# 1995-01-10  15.43750  15.18750  15.28125  15.40625  4364000.0   8.016990
# 1995-01-11  15.59375  15.37500  15.59375  15.37500  3738400.0   8.000724
# 1995-01-12  15.53125  15.31250  15.37500  15.53125  3307600.0   8.082034
# 1995-01-13  15.84375  15.53125  15.59375  15.62500  3992800.0   8.176886
# 1995-01-16  15.96875  15.75000  15.90625  15.75000  3677200.0   8.242304
# 1995-01-17  15.81250  15.65625  15.71875  15.81250  2437600.0   8.275010
# 1995-01-18  15.75000  15.43750  15.68750  15.46875  3535200.0   8.095115
# ...

# %%
PG.tail(20)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-05-03  135.679993  134.029999  134.029999  135.000000   8070300.0
# 2021-05-04  135.830002  134.210007  134.979996  134.539993   9624000.0
# 2021-05-05  134.470001  133.369995  134.369995  133.460007   5683100.0
# 2021-05-06  135.369995  133.919998  134.009995  135.139999   9771100.0
# 2021-05-07  136.029999  134.759995  135.080002  135.149994   6299100.0
# 2021-05-10  138.419998  135.690002  135.889999  137.669998   8852700.0
# 2021-05-11  138.789993  136.470001  138.490005  136.990005  10973700.0
# 2021-05-12  137.000000  135.490005  136.490005  135.539993   8853700.0
# 2021-05-13  138.529999  135.389999  135.889999  137.720001   8753600.0
# 2021-05-14  139.100006  137.669998  137.669998  138.009995   5989500.0
# 2021-05-17  139.070007  137.610001  137.970001  137.729996   7690700.0
# 2021-05-18  137.830002  136.149994  136.460007  136.320007   9239100.0
# ...

# %%
# Empresas: Procter&Gamble, Microsoft, AT&T, Ford, General Electric
# Extrair os dados de 'Adj Close' - Fechamento Ajustado

# %%
tickers = ['PG','MSFT','T','F','GE']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source='yahoo', start='1995-1-1')['Adj Close']

# %%
new_data.tail()
# Out:
#                     PG        MSFT          T      F     GE
# Date
# 2021-05-24  137.960007  250.779999  29.750000  13.06  13.18
# 2021-05-25  138.429993  251.720001  29.520000  12.81  13.12
# 2021-05-26  138.119995  251.490005  29.549999  13.90  13.40
# 2021-05-27  134.979996  249.309998  29.709999  14.88  14.35
# 2021-05-28  134.850006  249.679993  29.430000  14.53  14.06

# %%
## Importando os dados por outras fontes

# %%
import numpy as np
import pandas as pd

# %%
from pandas_datareader import data as wb

# %%
PG = wb.DataReader('PG', data_source = 'iex', start = '2018-01-01')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-8343298e2d72> in <module>
# ----> 1 PG = wb.DataReader('PG', data_source = 'iex', start = '2018-01-01')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     394             retry_count=retry_count,
#     395             pause=pause,
# --> 396             session=session,
#     397         ).read()
#     398
#
# ...

# %%
PG = wb.DataReader('PG', data_source = 'morningstar', start = '1995-01-01')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-76-a938b857aaf3> in <module>
# ----> 1 PG = wb.DataReader('PG', data_source = 'morningstar', start = '1995-01-01')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     371     if data_source not in expected_source:
#     372         msg = "data_source=%r is not implemented" % data_source
# --> 373         raise NotImplementedError(msg)
#     374
#     375     if data_source == "yahoo":
#
# ...

# %%
PG = wb.DataReader('PG', data_source = 'yahoo', start = '1995-01-01')

# %%
PG
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 1995-01-03   15.625000   15.437500   15.468750   15.593750   3318400.0
# 1995-01-04   15.656250   15.312500   15.531250   15.468750   2218800.0
# 1995-01-05   15.437500   15.218750   15.375000   15.250000   2319600.0
# 1995-01-06   15.406250   15.156250   15.156250   15.281250   3438000.0
# 1995-01-09   15.406250   15.187500   15.343750   15.218750   1795200.0
# ...                ...         ...         ...         ...         ...
# 2021-05-24  138.800003  137.729996  138.000000  137.960007   6981300.0
# 2021-05-25  138.479996  136.750000  138.050003  138.429993   8142400.0
# 2021-05-26  138.860001  137.869995  138.789993  138.119995   8122900.0
# 2021-05-27  138.279999  134.660004  138.119995  134.979996  33095700.0
# 2021-05-28  136.130005  134.639999  135.149994  134.850006  10477100.0
#
#              Adj Close
# Date
# 1995-01-03    8.114557
# 1995-01-04    8.049510
# 1995-01-05    7.935676
# ...

# %%
tickers = ['PG','MSFT','T','F','GE']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source = 'yahoo', start = '1995-01-01')['Close']

# %%
new_data.tail()
# Out:
#                     PG        MSFT          T      F     GE
# Date
# 2021-05-24  137.960007  250.779999  29.750000  13.06  13.18
# 2021-05-25  138.429993  251.720001  29.520000  12.81  13.12
# 2021-05-26  138.119995  251.490005  29.549999  13.90  13.40
# 2021-05-27  134.979996  249.309998  29.709999  14.88  14.35
# 2021-05-28  134.850006  249.679993  29.430000  14.53  14.06

# %%
# Importando e Organizando seus dados no Python

## Impostando os dados de outras fontes: CSV,EXCEL...

# %%
import quandl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-82-c982d674eccd> in <module>
# ----> 1 import quandl
#
# ModuleNotFoundError: No module named 'quandl'

# %%
mydata_01 = quandl.get("FRED/GDP")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-c8e0e08372cf> in <module>
# ----> 1 mydata_01 = quandl.get("FRED/GDP")
#
# NameError: name 'quandl' is not defined

# %%
import pandas as pd

# %%
mydata_01.to_csv()

# %%
mydata_02 = pd.read_csv('C:/Users/patri/Documents/BancoDados_Python/Curso_Python_Financas/Data_02.csv')

# %%
mydata_02.head()
# Out:
#          Date    Open      High     Low     Close      Volume  Ex-Dividend  \
# 0  2017-03-03  136.63  137.3300  136.08  137.1300  11095605.0          0.0
# 1  2017-03-02  137.09  137.8200  136.31  136.7603  12243028.0          0.0
# 2  2017-03-01  136.47  137.4800  136.30  137.4200  16257010.0          0.0
# 3  2017-02-28  136.79  136.8050  134.75  135.5400  16112092.0          0.0
# 4  2017-02-27  135.26  137.1846  135.02  136.4100  14306668.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0          1.0     136.63   137.3300    136.08    137.1300   11095605.0
# 1          1.0     137.09   137.8200    136.31    136.7603   12243028.0
# 2          1.0     136.47   137.4800    136.30    137.4200   16257010.0
# 3          1.0     136.79   136.8050    134.75    135.5400   16112092.0
# 4          1.0     135.26   137.1846    135.02    136.4100   14306668.0

# %%
mydata_02.tail()
# Out:
#             Date   Open   High    Low    Close       Volume  Ex-Dividend  \
# 1200  2012-05-24  32.95  33.21  31.77  33.0300   50237200.0          0.0
# 1201  2012-05-23  31.37  32.50  31.36  32.0000   73600000.0          0.0
# 1202  2012-05-22  32.61  33.59  30.94  31.0000  101786600.0          0.0
# 1203  2012-05-21  36.53  36.66  33.00  34.0300  168192700.0          0.0
# 1204  2012-05-18  42.05  45.00  38.00  38.2318  573576400.0          0.0
#
#       Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 1200          1.0      32.95      33.21     31.77     33.0300   50237200.0
# 1201          1.0      31.37      32.50     31.36     32.0000   73600000.0
# 1202          1.0      32.61      33.59     30.94     31.0000  101786600.0
# 1203          1.0      36.53      36.66     33.00     34.0300  168192700.0
# 1204          1.0      42.05      45.00     38.00     38.2318  573576400.0

# %%
mydata_02.to_excel('C:/Users/patri/Documents/BancoDados_Python/Curso_Python_Financas/Data_02v2.xlsx')

# %%
mydata_03 = pd.read_excel('C:/Users/patri/Documents/BancoDados_Python/Curso_Python_Financas/Data_03.xlsx')

# %%
mydata_03
# Out:
#     Year     Gas Exp     Pop        Gasp  Income
# 0   1953    7.400000  159565   16.667999    8883
# 1   1954    7.800000  162391   17.028999    8685
# 2   1955    8.600000  165275   17.209999    9137
# 3   1956    9.400000  168221   17.729000    9436
# 4   1957   10.200000  171274   18.497000    9534
# 5   1958   10.600000  174141   18.316000    9343
# 6   1959   11.300000  177130   18.576000    9738
# 7   1960   12.000000  180760   19.112000    9770
# 8   1961   12.000000  183742   18.924000    9843
# 9   1962   12.600000  186590   19.042999   10226
# 10  1963   13.000000  189300   18.997000   10398
# 11  1964   13.600000  191927   18.872999   11051
# 12  1965   14.800000  194347   19.587000   11430
# 13  1966   16.000000  196599   20.038000   11981
# 14  1967   17.100000  198752   20.700001   12418
# 15  1968   18.600000  200745   21.004999   12932
# 16  1969   20.500000  202736   21.695999   13060
# 17  1970   21.900000  205089   21.889999   13567
# ...

# %%
## Alterando o Índice dos dados de sua Série Temporal

# %%
mydata_02.head()
# Out:
#          Date    Open      High     Low     Close      Volume  Ex-Dividend  \
# 0  2017-03-03  136.63  137.3300  136.08  137.1300  11095605.0          0.0
# 1  2017-03-02  137.09  137.8200  136.31  136.7603  12243028.0          0.0
# 2  2017-03-01  136.47  137.4800  136.30  137.4200  16257010.0          0.0
# 3  2017-02-28  136.79  136.8050  134.75  135.5400  16112092.0          0.0
# 4  2017-02-27  135.26  137.1846  135.02  136.4100  14306668.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0          1.0     136.63   137.3300    136.08    137.1300   11095605.0
# 1          1.0     137.09   137.8200    136.31    136.7603   12243028.0
# 2          1.0     136.47   137.4800    136.30    137.4200   16257010.0
# 3          1.0     136.79   136.8050    134.75    135.5400   16112092.0
# 4          1.0     135.26   137.1846    135.02    136.4100   14306668.0

# %%
mydata_02.tail()
# Out:
#             Date   Open   High    Low    Close       Volume  Ex-Dividend  \
# 1200  2012-05-24  32.95  33.21  31.77  33.0300   50237200.0          0.0
# 1201  2012-05-23  31.37  32.50  31.36  32.0000   73600000.0          0.0
# 1202  2012-05-22  32.61  33.59  30.94  31.0000  101786600.0          0.0
# 1203  2012-05-21  36.53  36.66  33.00  34.0300  168192700.0          0.0
# 1204  2012-05-18  42.05  45.00  38.00  38.2318  573576400.0          0.0
#
#       Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 1200          1.0      32.95      33.21     31.77     33.0300   50237200.0
# 1201          1.0      31.37      32.50     31.36     32.0000   73600000.0
# 1202          1.0      32.61      33.59     30.94     31.0000  101786600.0
# 1203          1.0      36.53      36.66     33.00     34.0300  168192700.0
# 1204          1.0      42.05      45.00     38.00     38.2318  573576400.0

# %%
mydata_02 = pd.read_csv('C:/Users/patri/Documents/BancoDados_Python/Curso_Python_Financas/Data_02.csv', index_col='Date')

# %%
mydata_02
# Out:
#               Open      High     Low     Close       Volume  Ex-Dividend  \
# Date
# 2017-03-03  136.63  137.3300  136.08  137.1300   11095605.0          0.0
# 2017-03-02  137.09  137.8200  136.31  136.7603   12243028.0          0.0
# 2017-03-01  136.47  137.4800  136.30  137.4200   16257010.0          0.0
# 2017-02-28  136.79  136.8050  134.75  135.5400   16112092.0          0.0
# 2017-02-27  135.26  137.1846  135.02  136.4100   14306668.0          0.0
# ...            ...       ...     ...       ...          ...          ...
# 2012-05-24   32.95   33.2100   31.77   33.0300   50237200.0          0.0
# 2012-05-23   31.37   32.5000   31.36   32.0000   73600000.0          0.0
# 2012-05-22   32.61   33.5900   30.94   31.0000  101786600.0          0.0
# 2012-05-21   36.53   36.6600   33.00   34.0300  168192700.0          0.0
# 2012-05-18   42.05   45.0000   38.00   38.2318  573576400.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# ...

# %%
mydata_03.tail()
# Out:
#     Year     Gas Exp     Pop        Gasp  Income
# 47  2000  175.699997  282429  100.000000   25380
# 48  2001  171.600006  285366   96.289001   25449
# 49  2002  163.399994  288217   90.404999   26352
# 50  2003  191.300003  291073  105.153999   26437
# 51  2004  224.500000  293951  123.901001   27113

# %%
mydata_03.set_index('Year')
# Out:
#          Gas Exp     Pop        Gasp  Income
# Year
# 1953    7.400000  159565   16.667999    8883
# 1954    7.800000  162391   17.028999    8685
# 1955    8.600000  165275   17.209999    9137
# 1956    9.400000  168221   17.729000    9436
# 1957   10.200000  171274   18.497000    9534
# 1958   10.600000  174141   18.316000    9343
# 1959   11.300000  177130   18.576000    9738
# 1960   12.000000  180760   19.112000    9770
# 1961   12.000000  183742   18.924000    9843
# 1962   12.600000  186590   19.042999   10226
# 1963   13.000000  189300   18.997000   10398
# 1964   13.600000  191927   18.872999   11051
# 1965   14.800000  194347   19.587000   11430
# 1966   16.000000  196599   20.038000   11981
# 1967   17.100000  198752   20.700001   12418
# 1968   18.600000  200745   21.004999   12932
# 1969   20.500000  202736   21.695999   13060
# 1970   21.900000  205089   21.889999   13567
# 1971   23.200001  207692   22.049999   14008
# 1972   24.400000  209924   22.336000   14270
# ...

# %%
mydata_03 = mydata_03.set_index('Year')

# %%
mydata_03
# Out:
#          Gas Exp     Pop        Gasp  Income
# Year
# 1953    7.400000  159565   16.667999    8883
# 1954    7.800000  162391   17.028999    8685
# 1955    8.600000  165275   17.209999    9137
# 1956    9.400000  168221   17.729000    9436
# 1957   10.200000  171274   18.497000    9534
# 1958   10.600000  174141   18.316000    9343
# 1959   11.300000  177130   18.576000    9738
# 1960   12.000000  180760   19.112000    9770
# 1961   12.000000  183742   18.924000    9843
# 1962   12.600000  186590   19.042999   10226
# 1963   13.000000  189300   18.997000   10398
# 1964   13.600000  191927   18.872999   11051
# 1965   14.800000  194347   19.587000   11430
# 1966   16.000000  196599   20.038000   11981
# 1967   17.100000  198752   20.700001   12418
# 1968   18.600000  200745   21.004999   12932
# 1969   20.500000  202736   21.695999   13060
# 1970   21.900000  205089   21.889999   13567
# 1971   23.200001  207692   22.049999   14008
# 1972   24.400000  209924   22.336000   14270
# ...
